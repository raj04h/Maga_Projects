# %% [markdown]
# # Drug Discovery
# * finding more effective drug in Cancer

# %% [markdown]
# Data(continuous) Feature selection,
# 1. Features- Drug name / Drug ID,Drug target / Target Pathway, Feature Name, feature_pos / n_feature_neg, Tissue Type /Screening Set
# 2. Target- ic50_effect_size
#
# Regression algorithm,
# 1. Linear Regression
# 2. Random Forest Regression
#
# Model Tunning,
# 1. Grid search
# 2. Random search
# 3. Cross validation

# %% [markdown]
# 1. Drug target / Target Pathway- mechanism of action
# 2. Feature Name- e.g. mutation or expression marker
# 3. n_feature_pos, n_feature_neg- count of samples with/without the feature
# 4. Tissue Type, Screening Set- Include	cellular context, batch effects

# %% [markdown]
# # Data collection

# %%
import pandas as pd

# %%
file="D:\Data centr\Exel_data\int data\Drug_data\ANOVA_drugstructure.csv"
drug=pd.read_csv(file)
drug
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\himan\AppData\Local\Temp\ipykernel_2852\2595401914.py:1: SyntaxWarning: invalid escape sequence '\D'
#   file="D:\Data centr\Exel_data\int data\Drug_data\ANOVA_drugstructure.csv"
#              Drug name  Drug ID               Drug target   Target Pathway  \
# 0         Camptothecin     1003                      TOP1  DNA replication
# 1         Camptothecin     1003                      TOP1  DNA replication
# 2         Camptothecin     1003                      TOP1  DNA replication
# 3          Vinblastine     1004  Microtubule destabiliser          Mitosis
# 4          Vinblastine     1004  Microtubule destabiliser          Mitosis
# ..                 ...      ...                       ...              ...
# 724        glutathione     2439     anti-oxidant proteins            Other
# 725  alpha-lipoic acid     2498                Metabolism       Metabolism
# 726  alpha-lipoic acid     2498                Metabolism       Metabolism
# 727  N-acetyl cysteine     2499                Metabolism       Metabolism
# 728  N-acetyl cysteine     2499                Metabolism       Metabolism
#
#     Feature Name  n_feature_pos  n_feature_neg  ic50_effect_size  \
# 0       BRAF_mut              7              9          0.195421
# 1       NRAS_mut              3             13          0.103043
# 2       TP53_mut             11              5          0.493862
# 3       BRAF_mut              7              7          1.208547
# 4       TP53_mut             10              4          0.083904
# ..           ...            ...            ...               ...
# 724     TP53_mut             10              4          1.170728
# 725     BRAF_mut              7              7          0.514371
# 726     TP53_mut             10              4          0.246146
# 727     BRAF_mut              7              7          0.456265
# 728     TP53_mut             10              4          0.073336
#
#      log_ic50_mean_pos  log_ic50_mean_neg  ...  feature_ic50_t_pval  \
# 0            -2.636756          -2.364783  ...             0.696746
# 1            -2.600806          -2.456763  ...             0.789126
# 2            -2.693520          -2.022323  ...             0.516005
# 3            -3.902313          -1.478744  ...             0.048016
# 4            -2.747887          -2.547131  ...             0.899866
# ..                 ...                ...  ...                  ...
# 724           9.782948           8.796603  ...             0.156151
# 725           7.992659           8.413229  ...             0.354927
# 726           8.143690           8.351079  ...             0.790235
# 727          10.366953          10.070208  ...             0.412002
# 728          10.232607          10.183515  ...             0.905008
#
#      feature_delta_mean_ic50  feature_pos_ic50_var  feature_neg_ic50_var  \
# 0                  -0.271973              1.233768              1.499314
# 1                  -0.144043              0.556091              1.492728
# 2                  -0.671197              0.957136              2.043171
# 3                  -2.423569              1.439966              2.443240
# 4                  -0.200756              2.296656              2.660113
# ..                       ...                   ...                   ...
# 724                 0.986345              0.762811              1.045764
# 725                -0.420570              0.799091              0.835775
# 726                -0.207389              0.542155              1.399189
# 727                 0.296746              0.754533              0.525993
# 728                 0.049091              0.671777              0.662239
#
#      feature_pval  tissue_pval  msi_pval        fdr  Tissue Type  \
# 0        0.704013          NaN       NaN   0.000000         THCA
# 1        0.874489          NaN       NaN   0.000000         THCA
# 2        0.375356          NaN       NaN   0.000000         THCA
# 3        0.043134          NaN       NaN   0.000000         THCA
# 4        0.889573          NaN       NaN   0.000000         THCA
# ..            ...          ...       ...        ...          ...
# 724      0.071242          NaN       NaN   0.000000         THCA
# 725      0.354890          NaN       NaN   0.000000         THCA
# 726      0.684708          NaN       NaN   0.000000         THCA
# 727      0.410046          NaN       NaN  82.009227         THCA
# 728      0.903399          NaN       NaN  90.339906         THCA
#
#      Screening Set
# 0            GDSC2
# 1            GDSC2
# 2            GDSC2
# 3            GDSC2
# 4            GDSC2
# ..             ...
# 724          GDSC2
# 725          GDSC2
# 726          GDSC2
# 727          GDSC2
# 728          GDSC2
#
# [729 rows x 22 columns]

# %%
print(drug.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 729 entries, 0 to 728
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Drug name                729 non-null    object
#  1   Drug ID                  729 non-null    int64
#  2   Drug target              651 non-null    object
#  3   Target Pathway           725 non-null    object
#  4   Feature Name             729 non-null    object
#  5   n_feature_pos            729 non-null    int64
#  6   n_feature_neg            729 non-null    int64
#  7   ic50_effect_size         729 non-null    float64
#  8   log_ic50_mean_pos        729 non-null    float64
#  9   log_ic50_mean_neg        729 non-null    float64
#  10  log_max_conc_tested      0 non-null      float64
#  11  log_max_conc_tested_2    0 non-null      float64
#  12  feature_ic50_t_pval      729 non-null    float64
#  13  feature_delta_mean_ic50  729 non-null    float64
#  14  feature_pos_ic50_var     729 non-null    float64
#  15  feature_neg_ic50_var     729 non-null    float64
#  16  feature_pval             729 non-null    float64
#  17  tissue_pval              0 non-null      float64
#  18  msi_pval                 0 non-null      float64
#  19  fdr                      729 non-null    float64
#  20  Tissue Type              729 non-null    object
#  21  Screening Set            729 non-null    object
# dtypes: float64(13), int64(3), object(6)
# memory usage: 125.4+ KB
# None

# %% [markdown]
# # Data Statistics

# %%
drug.describe().T
# Out:
#                          count         mean         std           min  \
# Drug ID                  729.0  1586.717421  395.838548  1.003000e+03
# n_feature_pos            729.0     7.278464    2.775103  3.000000e+00
# n_feature_neg            729.0     7.278464    3.374613  3.000000e+00
# ic50_effect_size         729.0     0.506895    0.423942  2.357518e-03
# log_ic50_mean_pos        729.0     3.078876    2.538944 -5.731164e+00
# log_ic50_mean_neg        729.0     3.470456    2.464238 -6.038549e+00
# log_max_conc_tested        0.0          NaN         NaN           NaN
# log_max_conc_tested_2      0.0          NaN         NaN           NaN
# feature_ic50_t_pval      729.0     0.524623    0.296599  4.360000e-07
# feature_delta_mean_ic50  729.0    -0.391580    0.760352 -3.881385e+00
# feature_pos_ic50_var     729.0     1.095373    0.512299  6.329157e-02
# feature_neg_ic50_var     729.0     1.606060    0.678257  2.147008e-01
# feature_pval             729.0     0.487038    0.295581  4.300000e-07
# tissue_pval                0.0          NaN         NaN           NaN
# msi_pval                   0.0          NaN         NaN           NaN
# fdr                      729.0    19.768196   36.261223  0.000000e+00
#
#                                  25%          50%          75%          max
# Drug ID                  1133.000000  1629.000000  1910.000000  2499.000000
# n_feature_pos               7.000000     7.000000    10.000000    11.000000
# n_feature_neg               5.000000     7.000000     9.000000    13.000000
# ic50_effect_size            0.202754     0.414605     0.718827     5.255306
# log_ic50_mean_pos           2.106346     3.600376     4.833166    10.820421
# log_ic50_mean_neg           2.539563     3.965054     5.203400    10.678402
# log_max_conc_tested              NaN          NaN          NaN          NaN
# log_max_conc_tested_2            NaN          NaN          NaN          NaN
# feature_ic50_t_pval         0.261863     0.550121     0.780840     0.996932
# feature_delta_mean_ic50    -0.834684    -0.348769     0.066614     2.928332
# feature_pos_ic50_var        0.718433     0.999154     1.373065     4.170348
# feature_neg_ic50_var        1.123836     1.476371     1.939930     4.633970
# feature_pval                0.217854     0.486850     0.743273     0.997115
# tissue_pval                      NaN          NaN          NaN          NaN
# msi_pval                         NaN          NaN          NaN          NaN
# fdr                         0.000000     0.000000    11.926549    99.711519

# %%
drug.isnull().sum()
# Out:
# Drug name                    0
# Drug ID                      0
# Drug target                 78
# Target Pathway               4
# Feature Name                 0
# n_feature_pos                0
# n_feature_neg                0
# ic50_effect_size             0
# log_ic50_mean_pos            0
# log_ic50_mean_neg            0
# log_max_conc_tested        729
# log_max_conc_tested_2      729
# feature_ic50_t_pval          0
# feature_delta_mean_ic50      0
# feature_pos_ic50_var         0
# feature_neg_ic50_var         0
# feature_pval                 0
# tissue_pval                729
# msi_pval                   729
# fdr                          0
# Tissue Type                  0
# Screening Set                0
# dtype: int64

# %% [markdown]
# # Graph visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
drug.hist(figsize=(15,10),bins=10,color="yellow",edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'Drug ID'}>,
#         <Axes: title={'center': 'n_feature_pos'}>,
#         <Axes: title={'center': 'n_feature_neg'}>,
#         <Axes: title={'center': 'ic50_effect_size'}>],
#        [<Axes: title={'center': 'log_ic50_mean_pos'}>,
#         <Axes: title={'center': 'log_ic50_mean_neg'}>,
#         <Axes: title={'center': 'log_max_conc_tested'}>,
#         <Axes: title={'center': 'log_max_conc_tested_2'}>],
#        [<Axes: title={'center': 'feature_ic50_t_pval'}>,
#         <Axes: title={'center': 'feature_delta_mean_ic50'}>,
#         <Axes: title={'center': 'feature_pos_ic50_var'}>,
#         <Axes: title={'center': 'feature_neg_ic50_var'}>],
#        [<Axes: title={'center': 'feature_pval'}>,
#         <Axes: title={'center': 'tissue_pval'}>,
#         <Axes: title={'center': 'msi_pval'}>,
#         <Axes: title={'center': 'fdr'}>]], dtype=object)

# %%
# List of features for histograms
features = [
    'ic50_effect_size', 
    'n_feature_pos', 
    'n_feature_neg', 
    'log_ic50_mean_pos', 
    'log_ic50_mean_neg', 
    'feature_ic50_t_pval', 
    'feature_delta_mean_ic50', 
    'feature_pos_ic50_var', 
    'feature_neg_ic50_var'
]

# %%
# Plot histograms
for feature in features:
    plt.figure(figsize=(10,5))
    sb.histplot(drug[feature], kde=True, bins=30,color='pink', edgecolor='black')
    plt.title(f'Histogram of {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.show()

# %%
# pairs of feature
pairs = [
    ('n_feature_pos', 'ic50_effect_size'),
    ('n_feature_neg', 'ic50_effect_size'),
    ('log_ic50_mean_pos', 'ic50_effect_size'),
    ('log_ic50_mean_neg', 'ic50_effect_size'),
    ('feature_delta_mean_ic50', 'ic50_effect_size'),
    ('feature_pos_ic50_var', 'ic50_effect_size')
]

# %%
#plt.scatter(data=drug, x=feature_x, y=feature_y, alpha=0.7)
for (feature_x, feature_y) in pairs:
    plt.figure(figsize=(10, 5))
    sb.scatterplot(drug, x=feature_x, y=feature_y, alpha=0.7, color='green', edgecolor='white')
    plt.title(f'Scatter Plot of {feature_y} vs {feature_x}')
    plt.xlabel(feature_x)
    plt.ylabel(feature_y)
    plt.show()

# %%
plt.figure(figsize=(10, 5))
sb.displot(drug,kde=True)
plt.show()

# %% [markdown]
# # Correlation Matrix

# %%
from sklearn.preprocessing import LabelEncoder

# %%
drug_encoded=drug.copy()
le=LabelEncoder()
corr_matrix=drug_encoded[features].corr()
print(corr_matrix)
# Out:
#                          ic50_effect_size  n_feature_pos  n_feature_neg  \
# ic50_effect_size                 1.000000       0.028190      -0.077730
# n_feature_pos                    0.028190       1.000000      -0.872079
# n_feature_neg                   -0.077730      -0.872079       1.000000
# log_ic50_mean_pos               -0.088022       0.030104      -0.047721
# log_ic50_mean_neg                0.072115       0.031707      -0.061292
# feature_ic50_t_pval             -0.838342       0.014672      -0.017340
# feature_delta_mean_ic50         -0.527639      -0.002235       0.039294
# feature_pos_ic50_var            -0.151268      -0.230420       0.198320
# feature_neg_ic50_var            -0.079549       0.307203      -0.312289
#
#                          log_ic50_mean_pos  log_ic50_mean_neg  \
# ic50_effect_size                 -0.088022           0.072115
# n_feature_pos                     0.030104           0.031707
# n_feature_neg                    -0.047721          -0.061292
# log_ic50_mean_pos                 1.000000           0.954244
# log_ic50_mean_neg                 0.954244           1.000000
# feature_ic50_t_pval               0.103680          -0.057369
# feature_delta_mean_ic50           0.246544          -0.054536
# feature_pos_ic50_var             -0.201586          -0.225510
# feature_neg_ic50_var             -0.349917          -0.334255
#
#                          feature_ic50_t_pval  feature_delta_mean_ic50  \
# ic50_effect_size                   -0.838342                -0.527639
# n_feature_pos                       0.014672                -0.002235
# n_feature_neg                      -0.017340                 0.039294
# log_ic50_mean_pos                   0.103680                 0.246544
# log_ic50_mean_neg                  -0.057369                -0.054536
# feature_ic50_t_pval                 1.000000                 0.532136
# feature_delta_mean_ic50             0.532136                 1.000000
# feature_pos_ic50_var                0.213257                 0.057730
# feature_neg_ic50_var                0.135911                -0.085138
#
#                          feature_pos_ic50_var  feature_neg_ic50_var
# ic50_effect_size                    -0.151268             -0.079549
# n_feature_pos                       -0.230420              0.307203
# n_feature_neg                        0.198320             -0.312289
# log_ic50_mean_pos                   -0.201586             -0.349917
# log_ic50_mean_neg                   -0.225510             -0.334255
# feature_ic50_t_pval                  0.213257              0.135911
# feature_delta_mean_ic50              0.057730             -0.085138
# feature_pos_ic50_var                 1.000000              0.288950
# feature_neg_ic50_var                 0.288950              1.000000

# %%
plt.figure(figsize=(30,5))
sb.countplot(drug_encoded)
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(8,8))
sb.heatmap(corr_matrix,annot=True,cmap='coolwarm',fmt='.2f',linewidths=0.5,linecolor='white')
plt.title("Correlation Matrix of Drug Efficacy Features")
plt.show()

# %%
sb.pairplot(drug_encoded[features + ['Target Pathway']], hue='Target Pathway', palette='Set2')
plt.show()

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Feature Selection

# %%
numerical_colmn=['n_feature_pos', 
            'n_feature_neg', 
            'ic50_effect_size', 
            'log_ic50_mean_pos', 
            'log_ic50_mean_neg', 
            'feature_ic50_t_pval', 
            'feature_delta_mean_ic50', 
            'feature_pos_ic50_var', 
            'feature_neg_ic50_var', 
            'feature_pval', 
            'fdr']

drug[numerical_colmn]=drug[numerical_colmn].fillna(drug[numerical_colmn].mean())

categorical_column =['Drug target', 
                     'Target Pathway', 
                     'Drug name', 
                     'Feature Name', 
                     'Tissue Type',
                     'Screening Set']

drug[categorical_column]=drug[categorical_column].fillna(drug[categorical_column].mode().iloc[0])

# %%
# Handle columns that are entirely NaN (e.g., log_max_conc_tested, tissue_pval, msi_pval)
drug['log_max_conc_tested'] = drug['log_max_conc_tested'].fillna(drug['log_max_conc_tested'].mean())
drug['log_max_conc_tested_2'] = drug['log_max_conc_tested_2'].fillna(drug['log_max_conc_tested_2'].mean())
drug['tissue_pval'] = drug['tissue_pval'].fillna(drug['tissue_pval'].mean())
drug['msi_pval'] = drug['msi_pval'].fillna(drug['msi_pval'].mean())

# Verify that all missing values have been filled
print(drug.isnull().sum())
# Out:
# Drug name                    0
# Drug ID                      0
# Drug target                  0
# Target Pathway               0
# Feature Name                 0
# n_feature_pos                0
# n_feature_neg                0
# ic50_effect_size             0
# log_ic50_mean_pos            0
# log_ic50_mean_neg            0
# log_max_conc_tested        729
# log_max_conc_tested_2      729
# feature_ic50_t_pval          0
# feature_delta_mean_ic50      0
# feature_pos_ic50_var         0
# feature_neg_ic50_var         0
# feature_pval                 0
# tissue_pval                729
# msi_pval                   729
# fdr                          0
# Tissue Type                  0
# Screening Set                0
# dtype: int64

# %%
drug.head()
# Out:
#       Drug name  Drug ID               Drug target   Target Pathway  \
# 0  Camptothecin     1003                      TOP1  DNA replication
# 1  Camptothecin     1003                      TOP1  DNA replication
# 2  Camptothecin     1003                      TOP1  DNA replication
# 3   Vinblastine     1004  Microtubule destabiliser          Mitosis
# 4   Vinblastine     1004  Microtubule destabiliser          Mitosis
#
#   Feature Name  n_feature_pos  n_feature_neg  ic50_effect_size  \
# 0     BRAF_mut              7              9          0.195421
# 1     NRAS_mut              3             13          0.103043
# 2     TP53_mut             11              5          0.493862
# 3     BRAF_mut              7              7          1.208547
# 4     TP53_mut             10              4          0.083904
#
#    log_ic50_mean_pos  log_ic50_mean_neg  ...  feature_ic50_t_pval  \
# 0          -2.636756          -2.364783  ...             0.696746
# 1          -2.600806          -2.456763  ...             0.789126
# 2          -2.693520          -2.022323  ...             0.516005
# 3          -3.902313          -1.478744  ...             0.048016
# 4          -2.747887          -2.547131  ...             0.899866
#
#    feature_delta_mean_ic50  feature_pos_ic50_var  feature_neg_ic50_var  \
# 0                -0.271973              1.233768              1.499314
# 1                -0.144043              0.556091              1.492728
# 2                -0.671197              0.957136              2.043171
# 3                -2.423569              1.439966              2.443240
# 4                -0.200756              2.296656              2.660113
#
#    feature_pval  tissue_pval  msi_pval  fdr  Tissue Type  Screening Set
# 0      0.704013          NaN       NaN  0.0         THCA          GDSC2
# 1      0.874489          NaN       NaN  0.0         THCA          GDSC2
# 2      0.375356          NaN       NaN  0.0         THCA          GDSC2
# 3      0.043134          NaN       NaN  0.0         THCA          GDSC2
# 4      0.889573          NaN       NaN  0.0         THCA          GDSC2
#
# [5 rows x 22 columns]

# %% [markdown]
# # ML Algorithm (Model Training)

# %% [markdown]
# * for continuous data we use Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
x = drug_encoded.drop('ic50_effect_size', axis=1)  # Features
y = drug_encoded['ic50_effect_size']               # Target

# %% [markdown]
# Feature Importance Indices

# %%
for col in x.select_dtypes(include=['object']).columns:
    x[col] = le.fit_transform(x[col])

# Train a Decision Tree model
model = DecisionTreeRegressor()
model.fit(x, y)

# Get feature importance from the model
feature_importance = pd.DataFrame({'Feature': x.columns, 'Importance': model.feature_importances_})

# Sort by importance
feature_importance = feature_importance.sort_values(by='Importance', ascending=False)
print(feature_importance)
# Out:
#                     Feature  Importance
# 15             feature_pval    0.951925
# 2               Drug target    0.034705
# 6             n_feature_neg    0.005447
# 11      feature_ic50_t_pval    0.001620
# 5             n_feature_pos    0.001589
# 4              Feature Name    0.001062
# 1                   Drug ID    0.000922
# 13     feature_pos_ic50_var    0.000714
# 3            Target Pathway    0.000580
# 14     feature_neg_ic50_var    0.000391
# 8         log_ic50_mean_neg    0.000374
# 18                      fdr    0.000310
# 7         log_ic50_mean_pos    0.000227
# 12  feature_delta_mean_ic50    0.000077
# 0                 Drug name    0.000059
# 19              Tissue Type    0.000000
# 17                 msi_pval    0.000000
# 10    log_max_conc_tested_2    0.000000
# 16              tissue_pval    0.000000
# 9       log_max_conc_tested    0.000000
# 20            Screening Set    0.000000

# %% [markdown]
# # Feature Importance Visualize

# %%
plt.figure(figsize=(10,6))
sb.barplot(x="Importance",y="Feature",data=feature_importance)
plt.title("Features Importance")
plt.show()

# %%
top_feature=feature_importance['Feature'].head(5)
x_selected=x[top_feature]

# %% [markdown]
# # Data Spliting

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=40)

# %%
x_test
# Out:
#      Drug name  Drug ID  Drug target  Target Pathway  Feature Name  \
# 120        200     1058          124              18             0
# 353        121     1624           28               5             1
# 341        108     1618          122              14             1
# 694         65     2158           56               4             0
# 265         94     1511           15               7             2
# ..         ...      ...          ...             ...           ...
# 376         18     1634           79              14             0
# 579         99     1925           63              11             1
# 140         85     1069          141               6             1
# 62         234     1026           76              19             2
# 196        155     1179          166               2             1
#
#      n_feature_pos  n_feature_neg  log_ic50_mean_pos  log_ic50_mean_neg  \
# 120              7              9           1.174356           2.451900
# 353              3             11           2.456348           3.155157
# 341              3             11           4.615247           3.993459
# 694              7              7           3.970006           4.798596
# 265             11              5          -1.025137          -0.418551
# ..             ...            ...                ...                ...
# 376              7              7           4.222009           5.372409
# 579              3             13           5.653713           5.363489
# 140              3             13           4.148086           3.992545
# 62              11              5           0.243176          -0.079130
# 196              3             13           1.086205           1.509283
#
#      log_max_conc_tested  ...  feature_ic50_t_pval  feature_delta_mean_ic50  \
# 120                  NaN  ...             0.039486                -1.277545
# 353                  NaN  ...             0.421876                -0.698809
# 341                  NaN  ...             0.335745                 0.621789
# 694                  NaN  ...             0.133056                -0.828590
# 265                  NaN  ...             0.576546                -0.606585
# ..                   ...  ...                  ...                      ...
# 376                  NaN  ...             0.044609                -1.150400
# 579                  NaN  ...             0.732179                 0.290224
# 140                  NaN  ...             0.783082                 0.155541
# 62                   NaN  ...             0.713470                 0.322306
# 196                  NaN  ...             0.701879                -0.423078
#
#      feature_pos_ic50_var  feature_neg_ic50_var  feature_pval  tissue_pval  \
# 120              1.086521              1.141423      0.039755          NaN
# 353              1.124679              1.451377      0.458979          NaN
# 341              0.822627              1.030286      0.357987          NaN
# 694              0.856912              1.051434      0.132014          NaN
# 265              0.931775              2.172854      0.436259          NaN
# ..                    ...                   ...           ...          ...
# 376              1.043297              0.859287      0.043847          NaN
# 579              1.215868              1.134738      0.698686          NaN
# 140              0.732337              1.177635      0.832193          NaN
# 62               0.590099              1.795991      0.589399          NaN
# 196              1.569249              1.557595      0.678282          NaN
#
#      msi_pval        fdr  Tissue Type  Screening Set
# 120       NaN  11.926549            0              0
# 353       NaN  68.846890            0              0
# 341       NaN   0.000000            0              0
# 694       NaN   0.000000            0              0
# 265       NaN   0.000000            0              0
# ..        ...        ...          ...            ...
# 376       NaN   0.000000            0              0
# 579       NaN  98.362136            0              0
# 140       NaN   0.000000            0              0
# 62        NaN  88.409851            0              0
# 196       NaN  94.380880            0              0
#
# [146 rows x 21 columns]

# %%
x_train
# Out:
#      Drug name  Drug ID  Drug target  Target Pathway  Feature Name  \
# 719        230     2362          111              18             0
# 411        125     1738           82              12             2
# 712        215     2177           50               4             2
# 166        130     1088          154               7             0
# 106         41     1051           11              15             1
# ..         ...      ...          ...             ...           ...
# 440         38     1803          174              21             0
# 165         50     1086          131               2             2
# 7           74     1006           16              16             0
# 219         79     1248          113              14             0
# 326        139     1598          133              22             1
#
#      n_feature_pos  n_feature_neg  log_ic50_mean_pos  log_ic50_mean_neg  \
# 719              7              7           4.197154           5.523164
# 411              9              3           3.361646           2.406903
# 712             11              5           2.287091           2.573515
# 166              7              9           2.891946           3.541509
# 106              3             13           2.304914           2.718832
# ..             ...            ...                ...                ...
# 440              7              5           5.910602           4.617424
# 165             11              5           0.300095          -0.023015
# 7                7              7           2.390725           2.951333
# 219              3              6          -3.837401          -2.924370
# 326              3             13           5.046747           4.844830
#
#      log_max_conc_tested  ...  feature_ic50_t_pval  feature_delta_mean_ic50  \
# 719                  NaN  ...             0.044592                -1.326009
# 411                  NaN  ...             0.425893                 0.954743
# 712                  NaN  ...             0.707266                -0.286424
# 166                  NaN  ...             0.479227                -0.649563
# 106                  NaN  ...             0.523571                -0.413918
# ..                   ...  ...                  ...                      ...
# 440                  NaN  ...             0.292485                 1.293178
# 165                  NaN  ...             0.867173                 0.323110
# 7                    NaN  ...             0.621082                -0.560608
# 219                  NaN  ...             0.596954                -0.913031
# 326                  NaN  ...             0.641169                 0.201917
#
#      feature_pos_ic50_var  feature_neg_ic50_var  feature_pval  tissue_pval  \
# 719              0.981739              1.208282      0.043723          NaN
# 411              1.217922              1.633979      0.300538          NaN
# 712              0.556322              1.555003      0.586924          NaN
# 166              1.259495              2.261188      0.508096          NaN
# 106              0.706654              1.691873      0.690381          NaN
# ..                    ...                   ...           ...          ...
# 440              2.133963              1.864556      0.302258          NaN
# 165              1.815983              3.908542      0.820590          NaN
# 7                2.157536              1.971562      0.621008          NaN
# 219              1.449171              3.478878      0.683824          NaN
# 326              0.357701              1.331802      0.803077          NaN
#
#      msi_pval        fdr  Tissue Type  Screening Set
# 719       NaN   0.000000            0              0
# 411       NaN  60.107656            0              0
# 712       NaN   0.000000            0              0
# 166       NaN   0.000000            0              0
# 106       NaN   0.000000            0              0
# ..        ...        ...          ...            ...
# 440       NaN   0.000000            0              0
# 165       NaN   0.000000            0              0
# 7         NaN   0.000000            0              0
# 219       NaN  92.870557            0              0
# 326       NaN   0.000000            0              0
#
# [583 rows x 21 columns]

# %%
y_test
# Out:
# 120    1.142477
# 353    0.498358
# 341    0.622611
# 694    0.863909
# 265    0.432274
#          ...
# 376    1.203686
# 579    0.253099
# 140    0.138275
# 62     0.297931
# 196    0.271332
# Name: ic50_effect_size, Length: 146, dtype: float64

# %%
y_train
# Out:
# 719    1.204528
# 411    0.727848
# 712    0.299935
# 166    0.342276
# 106    0.260493
#          ...
# 440    0.636878
# 165    0.124639
# 7      0.271265
# 219    0.300288
# 326    0.162784
# Name: ic50_effect_size, Length: 583, dtype: float64

# %% [markdown]
# # Model Selection
# Data is continuous, Here we use Regression algorithm.

# %% [markdown]
# * Remove missing values

# %%
from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='mean')
x_train=imputer.fit_transform(x_train)
x_test=imputer.transform(x_test)
# Out:
# d:\Program_file\Anaconda\Lib\site-packages\sklearn\impute\_base.py:598: UserWarning: Skipping features without any observed values: ['log_max_conc_tested' 'log_max_conc_tested_2' 'tissue_pval' 'msi_pval']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# d:\Program_file\Anaconda\Lib\site-packages\sklearn\impute\_base.py:598: UserWarning: Skipping features without any observed values: ['log_max_conc_tested' 'log_max_conc_tested_2' 'tissue_pval' 'msi_pval']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
sb.lmplot(x='Drug ID',y='ic50_effect_size',data= drug)

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
reg_model=LinearRegression()
reg_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_reg=reg_model.predict(x_test)
MSE_lr = mean_squared_error(y_test, y_pred_reg)
MAE_lr = mean_absolute_error(y_test, y_pred_reg)
r2_lr = r2_score(y_test, y_pred_reg)

print("Mean Squared Error (MSE_lr):", MSE_lr)
print("Mean Absolute Error (MAE_lr):", MAE_lr)
print("R² Score:", r2_lr)
# Out:
# Mean Squared Error (MSE_lr): 0.04613131099037244
# Mean Absolute Error (MAE_lr): 0.10735795531342528
# R² Score: 0.7698560660936624

# %% [markdown]
# Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import label_binarize

# %%
# Train a Random Forest classifier
clf = RandomForestRegressor()
clf.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# Make predictions
y_pred_clf = clf.predict(x_test)

# Evaluate the model for regression
MSE_rfr = mean_absolute_error(y_test, y_pred_clf)
MAE_rfr = mean_squared_error(y_test, y_pred_clf)
r2_rfr = r2_score(y_test, y_pred_clf)

print("Mean Squared Error (MSE_rfr):", MSE_rfr)
print("Mean Absolute Error (MAE_rfr):", MAE_rfr)
print("R² Score:", r2_rfr)
# Out:
# Mean Squared Error (MSE_rfr): 0.03369658726863011
# Mean Absolute Error (MAE_rfr): 0.010597616215251467
# R² Score: 0.9471296819135148

# %%
labels = ['Linear Regression', 'Random Forest Regression']
MSE_values = [MSE_lr, MSE_rfr]
MAE_values = [MAE_lr, MAE_rfr]
R2_values = [r2_lr, r2_rfr]

fig, ax = plt.subplots(1, 3, figsize=(18, 6))
# MSE plot
ax[0].bar(labels, MSE_values, color=['blue', 'green'])
ax[0].set_title('Mean Squared Error (MSE)')
ax[0].set_ylabel('MSE')
ax[0].set_ylim([0, max(MSE_values) + 0.01])

# MAE plot
ax[1].bar(labels, MAE_values, color=['blue', 'green'])
ax[1].set_title('Mean Absolute Error (MAE)')
ax[1].set_ylabel('MAE')
ax[1].set_ylim([0, max(MAE_values) + 0.01])

# R² Score plot
ax[2].bar(labels, R2_values, color=['blue', 'green'])
ax[2].set_title('R² Score')
ax[2].set_ylabel('R² Score')
ax[2].set_ylim([0, 1])

plt.tight_layout()
plt.show()

# %% [markdown]
# # Model Tunning
# Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={
    'n_estimators': [50, 100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
grid_search=GridSearchCV(estimator=clf,param_grid=param_grid,cv=5,n_jobs=-1,verbose=2)

# %%
# Train the model using Grid Search
grid_search.fit(x_train, y_train)
print(f"Best Hyperparameters: {grid_search.best_params_}")
print(f"Best Cross-Validation Score: {grid_search.best_score_}")
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# Best Hyperparameters: {'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
# Best Cross-Validation Score: 0.9069899987460832

# %%
best_model = grid_search.best_estimator_
test_score_grid = best_model.score(x_test, y_test)
print(f"Test Set Accuracy: {test_score_grid}")
# Out:
# Test Set Accuracy: 0.96445794678338

# %% [markdown]
# Random search

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_search = RandomizedSearchCV(estimator=clf, param_distributions=param_grid, n_iter=20, cv=5, n_jobs=-1, verbose=2)

# %%
random_search.fit(x_train, y_train)
print(f"Best Hyperparameters: {random_search.best_params_}")
print(f"Best Cross-Validation Score: {random_search.best_score_}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Hyperparameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_depth': 20}
# Best Cross-Validation Score: 0.904644809625266

# %%
best_model_random = random_search.best_estimator_
test_score_random = best_model_random.score(x_test, y_test)
print(f"Test Set Accuracy: {test_score_random}")
# Out:
# Test Set Accuracy: 0.9653178746573784

# %% [markdown]
# Cross- Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
# Perform 5-fold cross-validation
cv_scores = cross_val_score(best_model, x_train, y_train, cv=5)
print(f"Cross-Validation Scores: {cv_scores}")
cv_mean=cv_scores.mean()
print(f"Mean CV Score: {cv_mean}")
# Out:
# Cross-Validation Scores: [0.63815889 0.95432647 0.98664234 0.97426685 0.94793348]
# Mean CV Score: 0.9002656049147838

# %%
labels = ['Grid Search', 'Random Search','Cross Validation']
Test_Accuracy = [test_score_grid, test_score_random,cv_mean]


fig, ax = plt.subplots(1,2, figsize=(10, 6))
# MSE plot
ax[0].bar(labels, Test_Accuracy, color=['blue', 'green','red'])
ax[0].set_title('Tunning Algorithm')
ax[0].set_ylabel('Test Accuracy')
ax[0].set_ylim([0, max(Test_Accuracy) + 0.01])

plt.tight_layout()
plt.show()

# %%
print(len(set(y_train))) # Check unique values in y_train
print(len(set(y_test)))    # Check unique values in y_test
# Out:
# 583
# 146

# %% [markdown]
# * Fully Connected Neural Network Model

# %%
import tensorflow as tf
import numpy as np

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
model_tensorflow = Sequential()   #  simplest ways to create neural networks in Keras, where layers are linear stacked on top of each other.
model_tensorflow.add(Dense(64, input_dim=x_train.shape[1], activation='relu')) # add layers to the model
model_tensorflow.add(Dense(32, activation='relu'))  # fully connected (dense) layer, meaning every neuron in the previous layer is connected to every neuron in the current layer.
model_tensorflow.add(Dense(1, activation='linear')) # neurons in this hidden layer is 64.Relu-transforms negative values to 0 and keeps positive values unchanged.
# linear, meaning no transformation is applied to the output;
model_tensorflow.compile(optimizer=Adam(), loss='mean_squared_error') #Adam optimizer is an adaptive optimization algorithm that computes adaptive learning rates for each parameter.
# Out:
# d:\Program_file\Anaconda\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
History = model_tensorflow.fit(x_train, y_train, epochs=50, batch_size=32, validation_split=0.2)

# Evaluate the model on the test set
test_loss = model_tensorflow.evaluate(x_test, y_test)
print(f"Test Loss: {test_loss}")
# Out:
# Epoch 1/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.2556 - val_loss: 0.1190
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0841 - val_loss: 0.0535
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0569 - val_loss: 0.0361
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0528 - val_loss: 0.0275
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0705 - val_loss: 0.0217
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0252 - val_loss: 0.0187
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0791 - val_loss: 0.0164
# Epoch 8/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0320 - val_loss: 0.0146
# Epoch 9/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0318 - val_loss: 0.0132
# Epoch 10/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0391 - val_loss: 0.0120
# Epoch 11/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0112 - val_loss: 0.0111
# Epoch 12/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0101 - val_loss: 0.0107
# Epoch 13/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0154 - val_loss: 0.0112
# Epoch 14/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0305 - val_loss: 0.0100
# Epoch 15/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0287 - val_loss: 0.0099
# Epoch 16/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0182 - val_loss: 0.0094
# Epoch 17/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0087 - val_loss: 0.0103
# Epoch 18/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0132 - val_loss: 0.0101
# Epoch 19/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0099 - val_loss: 0.0106
# Epoch 20/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0086 - val_loss: 0.0100
# Epoch 21/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0234 - val_loss: 0.0096
# Epoch 22/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0229 - val_loss: 0.0094
# Epoch 23/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0072 - val_loss: 0.0128
# Epoch 24/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071 - val_loss: 0.0097
# Epoch 25/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0186 - val_loss: 0.0099
# Epoch 26/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0076 - val_loss: 0.0119
# Epoch 27/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0125 - val_loss: 0.0106
# Epoch 28/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0063 - val_loss: 0.0110
# Epoch 29/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062 - val_loss: 0.0129
# Epoch 30/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071 - val_loss: 0.0105
# Epoch 31/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0044 - val_loss: 0.0116
# Epoch 32/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050 - val_loss: 0.0120
# Epoch 33/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0070 - val_loss: 0.0124
# Epoch 34/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0119 - val_loss: 0.0108
# Epoch 35/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0045 - val_loss: 0.0124
# Epoch 36/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0048 - val_loss: 0.0129
# Epoch 37/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0103 - val_loss: 0.0121
# Epoch 38/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - val_loss: 0.0124
# Epoch 39/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - val_loss: 0.0118
# Epoch 40/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0036 - val_loss: 0.0126
# Epoch 41/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028 - val_loss: 0.0128
# Epoch 42/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0025 - val_loss: 0.0136
# Epoch 43/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0035 - val_loss: 0.0131
# Epoch 44/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0047 - val_loss: 0.0122
# Epoch 45/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025 - val_loss: 0.0126
# Epoch 46/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024 - val_loss: 0.0138
# Epoch 47/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0023 - val_loss: 0.0126
# Epoch 48/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0034 - val_loss: 0.0125
# Epoch 49/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0045 - val_loss: 0.0121
# Epoch 50/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027 - val_loss: 0.0121
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0140
# Test Loss: 0.012215829454362392

# %%
labels=['MSE','MAE','R2']
Test_Accuracy=[test_mse,test_mae,test_r2]

fig, ax=plt.subplots(1,2, figsize=(10,6))

ax[0].bar(labels, Test_Accuracy, color=['blue','green','red'])
ax[0].set_title('Fully Connected Neural Network Algorithm')
ax[0].set_ylabel('Test Accuracy')
ax[0].set_ylim([0, max(Test_Accuracy) + 0.01])

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 2
#       1 labels=['MSE','MAE','R2']
# ----> 2 Test_Accuracy=[test_mse,test_mae,test_r2]
#       4 fig, ax=plt.subplots(1,2, figsize=(10,6))
#       6 ax[0].bar(labels, Test_Accuracy, color=['blue','green','red'])
#
# NameError: name 'test_mse' is not defined

# %% [markdown]
# * ResNet, Lr=0.0001

# %%
print(x_train.shape)
# Out:
# (583, 17)

# %%
def reshape_data(x):
    repeated_x = np.tile(x, (1, 181))  # (583, 17) → (583, 3077), cut 5 excess features
    resized_x = repeated_x[:, :3072].reshape(-1, 32, 32, 3)   # to match with image parameter
    return resized_x
x_train_reshaped=reshape_data(x_train)
x_test_reshaped=reshape_data(x_test)

print(x_train_reshaped.shape)
# Out:
# (583, 32, 32, 3)

# %%
from tensorflow.keras import layers, models

# %%
in_shape=(32, 32, 3)
model_res=tf.keras.applications.ResNet50(include_top=False, weights=None, input_shape=in_shape)
x=layers.GlobalAveragePooling2D()(model_res.output)
x=layers.Dense(64,activation='relu')(x)
x=layers.Dense(32,activation='relu')(x)
out_layer=layers.Dense(1,activation='linear')(x)

# %%
model_resnet=models.Model(inputs=model_res.input,outputs=out_layer)
model_resnet.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
model_resnet.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 38, 38, 3) │          0 │ input_layer_3[0]… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 16, 16,    │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 16, 16,    │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 16, 16,    │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 18, 18,    │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 8, 8, 64)  │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 8, 8, 64)  │      4,160 │ pool1_pool[0][0]  │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 8, 8, 64)  │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 8, 8, 64)  │          0 │ conv2_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 8, 8, 64)  │     36,928 │ conv2_block1_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 8, 8, 64)  │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 8, 8, 64)  │          0 │ conv2_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 8, 8, 256) │     16,640 │ pool1_pool[0][0]  │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 8, 8, 256) │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 8, 8, 256) │      1,024 │ conv2_block1_0_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_bn   │ (None, 8, 8, 256) │      1,024 │ conv2_block1_3_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_add    │ (None, 8, 8, 256) │          0 │ conv2_block1_0_b… │
# │ (Add)               │                   │            │ conv2_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 8, 8, 256) │          0 │ conv2_block1_add… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 8, 8, 64)  │     16,448 │ conv2_block1_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 8, 8, 64)  │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 8, 8, 64)  │          0 │ conv2_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 8, 8, 64)  │     36,928 │ conv2_block2_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 8, 8, 64)  │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 8, 8, 64)  │          0 │ conv2_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 8, 8, 256) │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_bn   │ (None, 8, 8, 256) │      1,024 │ conv2_block2_3_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_add    │ (None, 8, 8, 256) │          0 │ conv2_block1_out… │
# │ (Add)               │                   │            │ conv2_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 8, 8, 256) │          0 │ conv2_block2_add… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 8, 8, 64)  │     16,448 │ conv2_block2_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 8, 8, 64)  │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 8, 8, 64)  │          0 │ conv2_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 8, 8, 64)  │     36,928 │ conv2_block3_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 8, 8, 64)  │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 8, 8, 64)  │          0 │ conv2_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 8, 8, 256) │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_bn   │ (None, 8, 8, 256) │      1,024 │ conv2_block3_3_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_add    │ (None, 8, 8, 256) │          0 │ conv2_block2_out… │
# │ (Add)               │                   │            │ conv2_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 8, 8, 256) │          0 │ conv2_block3_add… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 4, 4, 128) │     32,896 │ conv2_block3_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 4, 4, 128) │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 4, 4, 128) │          0 │ conv3_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 4, 4, 128) │    147,584 │ conv3_block1_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 4, 4, 128) │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 4, 4, 128) │          0 │ conv3_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 4, 4, 512) │    131,584 │ conv2_block3_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 4, 4, 512) │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 4, 4, 512) │      2,048 │ conv3_block1_0_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_bn   │ (None, 4, 4, 512) │      2,048 │ conv3_block1_3_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_add    │ (None, 4, 4, 512) │          0 │ conv3_block1_0_b… │
# │ (Add)               │                   │            │ conv3_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 4, 4, 512) │          0 │ conv3_block1_add… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 4, 4, 128) │     65,664 │ conv3_block1_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 4, 4, 128) │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 4, 4, 128) │          0 │ conv3_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 4, 4, 128) │    147,584 │ conv3_block2_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 4, 4, 128) │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 4, 4, 128) │          0 │ conv3_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 4, 4, 512) │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_bn   │ (None, 4, 4, 512) │      2,048 │ conv3_block2_3_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_add    │ (None, 4, 4, 512) │          0 │ conv3_block1_out… │
# │ (Add)               │                   │            │ conv3_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 4, 4, 512) │          0 │ conv3_block2_add… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 4, 4, 128) │     65,664 │ conv3_block2_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 4, 4, 128) │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 4, 4, 128) │          0 │ conv3_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 4, 4, 128) │    147,584 │ conv3_block3_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 4, 4, 128) │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 4, 4, 128) │          0 │ conv3_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 4, 4, 512) │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_bn   │ (None, 4, 4, 512) │      2,048 │ conv3_block3_3_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_add    │ (None, 4, 4, 512) │          0 │ conv3_block2_out… │
# │ (Add)               │                   │            │ conv3_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 4, 4, 512) │          0 │ conv3_block3_add… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 4, 4, 128) │     65,664 │ conv3_block3_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 4, 4, 128) │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 4, 4, 128) │          0 │ conv3_block4_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 4, 4, 128) │    147,584 │ conv3_block4_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 4, 4, 128) │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 4, 4, 128) │          0 │ conv3_block4_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 4, 4, 512) │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_bn   │ (None, 4, 4, 512) │      2,048 │ conv3_block4_3_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_add    │ (None, 4, 4, 512) │          0 │ conv3_block3_out… │
# │ (Add)               │                   │            │ conv3_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 4, 4, 512) │          0 │ conv3_block4_add… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 2, 2, 256) │    131,328 │ conv3_block4_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 2, 2, 256) │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 2, 2, 256) │          0 │ conv4_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 2, 2, 256) │    590,080 │ conv4_block1_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 2, 2, 256) │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 2, 2, 256) │          0 │ conv4_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 2, 2,      │    525,312 │ conv3_block4_out… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 2, 2,      │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 2, 2,      │      4,096 │ conv4_block1_0_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_bn   │ (None, 2, 2,      │      4,096 │ conv4_block1_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_add    │ (None, 2, 2,      │          0 │ conv4_block1_0_b… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 2, 2,      │          0 │ conv4_block1_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 2, 2, 256) │    262,400 │ conv4_block1_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 2, 2, 256) │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 2, 2, 256) │          0 │ conv4_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 2, 2, 256) │    590,080 │ conv4_block2_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 2, 2, 256) │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 2, 2, 256) │          0 │ conv4_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 2, 2,      │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_bn   │ (None, 2, 2,      │      4,096 │ conv4_block2_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_add    │ (None, 2, 2,      │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 2, 2,      │          0 │ conv4_block2_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 2, 2, 256) │    262,400 │ conv4_block2_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 2, 2, 256) │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 2, 2, 256) │          0 │ conv4_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 2, 2, 256) │    590,080 │ conv4_block3_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 2, 2, 256) │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 2, 2, 256) │          0 │ conv4_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 2, 2,      │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_bn   │ (None, 2, 2,      │      4,096 │ conv4_block3_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_add    │ (None, 2, 2,      │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 2, 2,      │          0 │ conv4_block3_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 2, 2, 256) │    262,400 │ conv4_block3_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 2, 2, 256) │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 2, 2, 256) │          0 │ conv4_block4_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 2, 2, 256) │    590,080 │ conv4_block4_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 2, 2, 256) │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 2, 2, 256) │          0 │ conv4_block4_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 2, 2,      │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_bn   │ (None, 2, 2,      │      4,096 │ conv4_block4_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_add    │ (None, 2, 2,      │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 2, 2,      │          0 │ conv4_block4_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 2, 2, 256) │    262,400 │ conv4_block4_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 2, 2, 256) │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 2, 2, 256) │          0 │ conv4_block5_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 2, 2, 256) │    590,080 │ conv4_block5_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 2, 2, 256) │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 2, 2, 256) │          0 │ conv4_block5_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 2, 2,      │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_bn   │ (None, 2, 2,      │      4,096 │ conv4_block5_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_add    │ (None, 2, 2,      │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 2, 2,      │          0 │ conv4_block5_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 2, 2, 256) │    262,400 │ conv4_block5_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 2, 2, 256) │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 2, 2, 256) │          0 │ conv4_block6_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 2, 2, 256) │    590,080 │ conv4_block6_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 2, 2, 256) │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 2, 2, 256) │          0 │ conv4_block6_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 2, 2,      │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_bn   │ (None, 2, 2,      │      4,096 │ conv4_block6_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_add    │ (None, 2, 2,      │          0 │ conv4_block5_out… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 2, 2,      │          0 │ conv4_block6_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 1, 1, 512) │    524,800 │ conv4_block6_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 1, 1, 512) │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 1, 1, 512) │          0 │ conv5_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 1, 1, 512) │  2,359,808 │ conv5_block1_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 1, 1, 512) │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 1, 1, 512) │          0 │ conv5_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 1, 1,      │  2,099,200 │ conv4_block6_out… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 1, 1,      │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_bn   │ (None, 1, 1,      │      8,192 │ conv5_block1_0_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_bn   │ (None, 1, 1,      │      8,192 │ conv5_block1_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_add    │ (None, 1, 1,      │          0 │ conv5_block1_0_b… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 1, 1,      │          0 │ conv5_block1_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 1, 1, 512) │  1,049,088 │ conv5_block1_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 1, 1, 512) │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 1, 1, 512) │          0 │ conv5_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 1, 1, 512) │  2,359,808 │ conv5_block2_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 1, 1, 512) │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 1, 1, 512) │          0 │ conv5_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 1, 1,      │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_bn   │ (None, 1, 1,      │      8,192 │ conv5_block2_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_add    │ (None, 1, 1,      │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 1, 1,      │          0 │ conv5_block2_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 1, 1, 512) │  1,049,088 │ conv5_block2_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 1, 1, 512) │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 1, 1, 512) │          0 │ conv5_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 1, 1, 512) │  2,359,808 │ conv5_block3_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 1, 1, 512) │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 1, 1, 512) │          0 │ conv5_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 1, 1,      │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_bn   │ (None, 1, 1,      │      8,192 │ conv5_block3_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_add    │ (None, 1, 1,      │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 1, 1,      │          0 │ conv5_block3_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ conv5_block3_out… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 64)        │    131,136 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 32)        │      2,080 │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 1)         │         33 │ dense_10[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 23,720,961 (90.49 MB)
#  Trainable params: 23,667,841 (90.29 MB)
#  Non-trainable params: 53,120 (207.50 KB)

# %%
model_resnet.fit(x_train_reshaped, y_train, epochs=50, batch_size=16, validation_data=(x_test_reshaped, y_test))
# Out:
# Epoch 1/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 68s 394ms/step - loss: 1.7426 - mae: 0.7664 - val_loss: 0.4420 - val_mae: 0.4968
# Epoch 2/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 268ms/step - loss: 0.2666 - mae: 0.3412 - val_loss: 0.2627 - val_mae: 0.3472
# Epoch 3/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 263ms/step - loss: 0.1322 - mae: 0.2390 - val_loss: 0.2104 - val_mae: 0.3195
# Epoch 4/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 280ms/step - loss: 0.3112 - mae: 0.2849 - val_loss: 0.1972 - val_mae: 0.3135
# Epoch 5/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 12s 336ms/step - loss: 0.1295 - mae: 0.2103 - val_loss: 0.1948 - val_mae: 0.3077
# Epoch 6/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 18s 273ms/step - loss: 0.1856 - mae: 0.2300 - val_loss: 0.1784 - val_mae: 0.3160
# Epoch 7/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 272ms/step - loss: 0.1146 - mae: 0.2064 - val_loss: 0.1680 - val_mae: 0.2912
# Epoch 8/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 11s 296ms/step - loss: 0.0907 - mae: 0.2011 - val_loss: 0.2096 - val_mae: 0.2754
# Epoch 9/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 19s 270ms/step - loss: 0.1112 - mae: 0.1985 - val_loss: 0.1950 - val_mae: 0.2798
# Epoch 10/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 10s 269ms/step - loss: 0.0959 - mae: 0.1828 - val_loss: 4.2556 - val_mae: 0.9375
# Epoch 11/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 11s 300ms/step - loss: 0.0777 - mae: 0.1957 - val_loss: 1.2065 - val_mae: 0.5511
# Epoch 12/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 12s 309ms/step - loss: 0.0817 - mae: 0.1874 - val_loss: 0.1333 - val_mae: 0.2381
# Epoch 13/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 9s 237ms/step - loss: 0.0802 - mae: 0.1711 - val_loss: 0.1843 - val_mae: 0.3202
# Epoch 14/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 227ms/step - loss: 0.0732 - mae: 0.1760 - val_loss: 0.1840 - val_mae: 0.3219
# Epoch 15/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 9s 238ms/step - loss: 0.0535 - mae: 0.1586 - val_loss: 0.2339 - val_mae: 0.3873
# Epoch 16/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 9s 250ms/step - loss: 0.0542 - mae: 0.1713 - val_loss: 0.2827 - val_mae: 0.4058
# Epoch 17/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 9s 240ms/step - loss: 0.0863 - mae: 0.1956 - val_loss: 0.1317 - val_mae: 0.2745
# Epoch 18/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 195ms/step - loss: 0.0835 - mae: 0.1916 - val_loss: 0.1096 - val_mae: 0.2190
# Epoch 19/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - loss: 0.0376 - mae: 0.1406 - val_loss: 0.0957 - val_mae: 0.2238
# Epoch 20/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 200ms/step - loss: 0.0274 - mae: 0.1201 - val_loss: 0.1239 - val_mae: 0.2163
# Epoch 21/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - loss: 0.0553 - mae: 0.1802 - val_loss: 0.2372 - val_mae: 0.2580
# Epoch 22/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 215ms/step - loss: 0.0390 - mae: 0.1490 - val_loss: 0.0973 - val_mae: 0.2105
# Epoch 23/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 200ms/step - loss: 0.0312 - mae: 0.1240 - val_loss: 0.0831 - val_mae: 0.1672
# Epoch 24/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 228ms/step - loss: 0.0416 - mae: 0.1370 - val_loss: 0.1216 - val_mae: 0.2523
# Epoch 25/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 221ms/step - loss: 0.0477 - mae: 0.1450 - val_loss: 0.0846 - val_mae: 0.1814
# Epoch 26/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 229ms/step - loss: 0.0548 - mae: 0.1513 - val_loss: 0.1174 - val_mae: 0.2018
# Epoch 27/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 207ms/step - loss: 0.0406 - mae: 0.1410 - val_loss: 0.0830 - val_mae: 0.1813
# Epoch 28/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - loss: 0.0290 - mae: 0.1157 - val_loss: 0.0935 - val_mae: 0.1908
# Epoch 29/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 189ms/step - loss: 0.0469 - mae: 0.1323 - val_loss: 0.0846 - val_mae: 0.1833
# Epoch 30/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 189ms/step - loss: 0.0339 - mae: 0.1336 - val_loss: 0.0789 - val_mae: 0.1620
# Epoch 31/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 204ms/step - loss: 0.0329 - mae: 0.1211 - val_loss: 0.0871 - val_mae: 0.1686
# Epoch 32/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 9s 246ms/step - loss: 0.0262 - mae: 0.1157 - val_loss: 0.0645 - val_mae: 0.1455
# Epoch 33/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 209ms/step - loss: 0.0225 - mae: 0.1029 - val_loss: 0.0933 - val_mae: 0.2098
# Epoch 34/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 215ms/step - loss: 0.0443 - mae: 0.1553 - val_loss: 0.0696 - val_mae: 0.1764
# Epoch 35/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 204ms/step - loss: 0.0499 - mae: 0.1535 - val_loss: 0.0916 - val_mae: 0.1943
# Epoch 36/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 193ms/step - loss: 0.0421 - mae: 0.1518 - val_loss: 0.1081 - val_mae: 0.2043
# Epoch 37/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 195ms/step - loss: 0.0562 - mae: 0.1668 - val_loss: 0.0893 - val_mae: 0.2031
# Epoch 38/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 195ms/step - loss: 0.0503 - mae: 0.1496 - val_loss: 0.3242 - val_mae: 0.4359
# Epoch 39/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 192ms/step - loss: 0.1265 - mae: 0.2401 - val_loss: 0.1424 - val_mae: 0.2526
# Epoch 40/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 191ms/step - loss: 0.1374 - mae: 0.2035 - val_loss: 0.1779 - val_mae: 0.2501
# Epoch 41/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 189ms/step - loss: 0.0750 - mae: 0.1908 - val_loss: 0.1525 - val_mae: 0.2516
# Epoch 42/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 189ms/step - loss: 0.1832 - mae: 0.2051 - val_loss: 0.2354 - val_mae: 0.2800
# Epoch 43/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 202ms/step - loss: 0.1666 - mae: 0.1980 - val_loss: 0.1431 - val_mae: 0.2336
# Epoch 44/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 208ms/step - loss: 0.1631 - mae: 0.1909 - val_loss: 0.1266 - val_mae: 0.2283
# Epoch 45/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 195ms/step - loss: 0.0618 - mae: 0.1416 - val_loss: 0.0961 - val_mae: 0.1899
# Epoch 46/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 200ms/step - loss: 0.0599 - mae: 0.1406 - val_loss: 0.1097 - val_mae: 0.2148
# Epoch 47/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 222ms/step - loss: 0.0347 - mae: 0.1308 - val_loss: 0.0512 - val_mae: 0.1469
# Epoch 48/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 8s 219ms/step - loss: 0.0960 - mae: 0.1927 - val_loss: 0.0950 - val_mae: 0.1966
# Epoch 49/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 198ms/step - loss: 0.0786 - mae: 0.1585 - val_loss: 0.0554 - val_mae: 0.1505
# Epoch 50/50
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 7s 196ms/step - loss: 0.0871 - mae: 0.1487 - val_loss: 0.0830 - val_mae: 0.1681

# %%
# Evaluate the model on test data
loss, mae = model_resnet.evaluate(x_test_reshaped, y_test)

# Print the evaluation results
print(f"Test Loss: {loss:.4f}")
print(f"Test Mean Absolute Error (MAE): {mae:.4f}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0928 - mae: 0.1780
# Test Loss: 0.0830
# Test Mean Absolute Error (MAE): 0.1681

# %%
y_pred = model_resnet.predict(x_test_reshaped)
y_test = np.array(y_test)  # Convert to NumPy array if it's a Pandas object
y_pred = np.array(y_pred)  # Ensure predictions are also NumPy arrays

# Print some sample predictions
import numpy as np
for i in range(5):
    print(f"Actual: {y_test[i]:.4f}, Predicted: {y_pred[i][0]:.4f}")
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002AD6D169E40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002AD6D169E40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/5 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/stepWARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002AD6D169E40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002AD6D169E40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 459ms/step
# Actual: 1.1425, Predicted: 0.8524
# Actual: 0.4984, Predicted: 0.3784
# Actual: 0.6226, Predicted: 0.3518
# Actual: 0.8639, Predicted: 0.6793
# Actual: 0.4323, Predicted: 0.4099

# %% [markdown]
# # Graph

# %%
plt.figure(figsize=(8,6))
plt.scatter(y_test, y_pred, alpha=0.5, label="Predictions")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='dashed', label="Ideal Fit")
plt.xlabel("Actual ic50 Values")
plt.ylabel("Predicted ic50 Values")
plt.legend()
plt.title("ResNet Model Performance")
plt.show()

# %% [markdown]
# # Model Deployement
# * tflite format, joblib

# %%
import joblib

# %%
joblib.dump(best_model_random,"drug_effectiveness_model.pkl")
# Out:
# ['drug_effectiveness_model.pkl']

# %%
# Save the model
model_tensorflow.save("drug_effectiveness.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
converter=tf.lite.TFLiteConverter.from_keras_model(model_tensorflow)
tflite_model=converter.convert()

with open('drug_effectiveness.tflite','wb') as f:
    f.write(tflite_model)
    print(help(tf.lite.TFLiteConverter))
# Out:
# INFO:tensorflow:Assets written to: C:\Users\himan\AppData\Local\Temp\tmprd89_icw\assets
# INFO:tensorflow:Assets written to: C:\Users\himan\AppData\Local\Temp\tmprd89_icw\assets
# Saved artifact at 'C:\Users\himan\AppData\Local\Temp\tmprd89_icw'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 17), dtype=tf.float32, name='keras_tensor_186')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   2944814819920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2944814819152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2943798536016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2944814817040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2944814818576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2944814812624: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Help on class TFLiteConverterV2 in module tensorflow.lite.python.lite:
#
# class TFLiteConverterV2(TFLiteFrozenGraphConverterV2)
#  |  TFLiteConverterV2(funcs, trackable_obj=None)
#  |
#  |  Converts a TensorFlow model into TensorFlow Lite model.
#  |
#  |  Attributes:
#  |    optimizations: Experimental flag, subject to change. Set of optimizations to
#  |      apply. e.g {tf.lite.Optimize.DEFAULT}. (default None, must be None or a
#  |      set of values of type `tf.lite.Optimize`)
#  |    representative_dataset: A generator function used for integer quantization
#  |      where each generated sample has the same order, type and shape as the
#  |      inputs to the model. Usually, this is a small subset of a few hundred
#  |      samples randomly chosen, in no particular order, from the training or
#  |      evaluation dataset. This is an optional attribute, but required for full
#  |      integer quantization, i.e, if `tf.int8` is the only supported type in
#  |      `target_spec.supported_types`. Refer to `tf.lite.RepresentativeDataset`.
#  |      (default None)
#  |    target_spec: Experimental flag, subject to change. Specifications of the
#  |      target device, including supported ops set, supported types and a set
#  |      of user's defined TensorFlow operators required in the TensorFlow Lite
#  |      runtime. Refer to `tf.lite.TargetSpec`.
#  |    inference_input_type: Data type of the input layer. Note that integer types
#  |      (tf.int8 and tf.uint8) are currently only supported for post-training
#  |      integer quantization and quantization-aware training. (default tf.float32,
#  |      must be in {tf.float32, tf.int8, tf.uint8})
#  |    inference_output_type: Data type of the output layer. Note that integer
#  |      types (tf.int8 and tf.uint8) are currently only supported for
#  |      post-training integer quantization and quantization-aware training.
#  |      (default tf.float32, must be in {tf.float32, tf.int8, tf.uint8})
#  |    allow_custom_ops: Boolean indicating whether to allow custom operations.
#  |      When False, any unknown operation is an error. When True, custom ops are
#  |      created for any op that is unknown. The developer needs to provide these
#  |      to the TensorFlow Lite runtime with a custom resolver. (default False)
#  |    exclude_conversion_metadata: Whether not to embed the conversion metadata
#  |      into the converted model. (default False)
#  |    experimental_new_converter: Experimental flag, subject to change. Enables
#  |      MLIR-based conversion. (default True)
#  |    experimental_new_quantizer: Experimental flag, subject to change. Enables
#  |      MLIR-based quantization conversion instead of Flatbuffer-based conversion.
#  |      (default True)
#  |    experimental_enable_resource_variables: Experimental flag, subject to
#  |      change. Enables [resource
#  |      variables](https://tensorflow.org/guide/migrate/tf1_vs_tf2#resourcevariables_instead_of_referencevariables)
#  |      to be converted by this converter. This is only allowed if the
#  |      from_saved_model interface is used. (default True)
#  |    serialize_debug_metadata: Enables serializing debug metadata into the TFLite
#  |      model. (default False)
#  |
#  |  Example usage:
#  |
#  |  ```python
#  |  # Converting a SavedModel to a TensorFlow Lite model.
#  |  converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_dir)
#  |  tflite_model = converter.convert()
#  |
#  |  # Converting a tf.Keras model to a TensorFlow Lite model.
#  |  converter = tf.lite.TFLiteConverter.from_keras_model(model)
#  |  tflite_model = converter.convert()
#  |
#  |  # Converting ConcreteFunctions to a TensorFlow Lite model.
#  |  converter = tf.lite.TFLiteConverter.from_concrete_functions([func], model)
#  |  tflite_model = converter.convert()
#  |
#  |  # Converting a Jax model to a TensorFlow Lite model.
#  |  converter = tf.lite.TFLiteConverter.experimental_from_jax(
#  |      [func], [[ ('input1', input1), ('input2', input2)]])
#  |  tflite_model = converter.convert()
#  |  ```
#  |
#  |  Method resolution order:
#  |      TFLiteConverterV2
#  |      TFLiteFrozenGraphConverterV2
#  |      TFLiteConverterBaseV2
#  |      TFLiteConverterBase
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, funcs, trackable_obj=None)
#  |      Constructor for TFLiteConverter.
#  |
#  |      Args:
#  |        funcs: List of TensorFlow ConcreteFunctions. The list should not contain
#  |          duplicate elements.
#  |        trackable_obj: tf.AutoTrackable object associated with `funcs`. A
#  |          reference to this object needs to be maintained so that Variables do not
#  |          get garbage collected since functions have a weak reference to
#  |          Variables. This is only required when the tf.AutoTrackable object is not
#  |          maintained by the user (e.g. `from_saved_model`).
#  |
#  |  convert(self)
#  |      Converts a TensorFlow GraphDef based on instance variables.
#  |
#  |      Returns:
#  |        The converted data in serialized format.
#  |
#  |      Raises:
#  |        ValueError:
#  |          No concrete function is specified.
#  |          Multiple concrete functions are specified.
#  |          Input shape is not specified.
#  |          Invalid quantization parameters.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  experimental_from_jax(serving_funcs, inputs)
#  |      Creates a TFLiteConverter object from a Jax model with its inputs. (deprecated)
#  |
#  |      Deprecated: THIS FUNCTION IS DEPRECATED. It will be removed in a future version.
#  |      Instructions for updating:
#  |      Use `jax2tf.convert` and (`lite.TFLiteConverter.from_saved_model` or `lite.TFLiteConverter.from_concrete_functions`) instead.
#  |
#  |      Args:
#  |        serving_funcs: An array of Jax functions with all the weights applied
#  |          already.
#  |        inputs: An array of Jax input placeholders tuples list, e.g.,
#  |          jnp.zeros(INPUT_SHAPE). Each tuple list should correspond with the
#  |          serving function.
#  |
#  |      Returns:
#  |        TFLiteConverter object.
#  |
#  |  from_concrete_functions(funcs, trackable_obj=None)
#  |      Creates a TFLiteConverter object from ConcreteFunctions.
#  |
#  |      Args:
#  |        funcs: List of TensorFlow ConcreteFunctions. The list should not contain
#  |          duplicate elements. Currently converter can only convert a single
#  |          ConcreteFunction. Converting multiple functions is under development.
#  |        trackable_obj:   An `AutoTrackable` object (typically `tf.module`)
#  |          associated with `funcs`. A reference to this object needs to be
#  |          maintained so that Variables do not get garbage collected since
#  |          functions have a weak reference to Variables.
#  |
#  |      Returns:
#  |        TFLiteConverter object.
#  |
#  |      Raises:
#  |        Invalid input type.
#  |
#  |  from_keras_model(model)
#  |      Creates a TFLiteConverter object from a Keras model.
#  |
#  |      Args:
#  |        model: tf.Keras.Model
#  |
#  |      Returns:
#  |        TFLiteConverter object.
#  |
#  |  from_saved_model(saved_model_dir, signature_keys=None, tags=None)
#  |      Creates a TFLiteConverter object from a SavedModel directory.
#  |
#  |      Args:
#  |        saved_model_dir: SavedModel directory to convert.
#  |        signature_keys: List of keys identifying SignatureDef containing inputs
#  |          and outputs. Elements should not be duplicated. By default the
#  |          `signatures` attribute of the MetaGraphdef is used. (default
#  |          saved_model.signatures)
#  |        tags: Set of tags identifying the MetaGraphDef within the SavedModel to
#  |          analyze. All tags in the tag set must be present. (default
#  |          {tf.saved_model.SERVING} or {'serve'})
#  |
#  |      Returns:
#  |        TFLiteConverter object.
#  |
#  |      Raises:
#  |        Invalid signature keys.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from TFLiteConverterBase:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#
# None

# %% [markdown]
# # Model Prediction

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Make predictions
y_pred = model_tensorflow.predict(x_test)

# If you have continuous targets, ensure y_pred and y_test are aligned
# Calculate regression metrics
test_mae = mean_absolute_error(y_test, y_pred)
test_mse = mean_squared_error(y_test, y_pred)
test_r2 = r2_score(y_test, y_pred)

print(f"Test Mean Absolute Error (MAE): {test_mae}")
print(f"Test Mean Squared Error (MSE): {test_mse}")
print(f"Test R² Score: {test_r2}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Test Mean Absolute Error (MAE): 0.08882332626571438
# Test Mean Squared Error (MSE): 0.013376319437261211
# Test R² Score: 0.9332670433510641

# %%
import torch
input_tensor = torch.randn(1, 17)  # Example tensor with shape (1, 17)
print(input_tensor) # 1 batch size, 17 features that model expects
# Out:
# tensor([[ 0.4222, -0.3295, -0.6285, -1.1519,  1.2240, -0.3703, -2.0775,  0.8561,
#           0.4149, -0.1430,  0.1457,  0.0027, -0.0974, -1.4700,  0.9574,  0.8588,
#          -0.6351]])

# %%
print(input_tensor.shape)  # combined array (drug name + numerical features) must have 17 elements
# Out:
# torch.Size([1, 17])

# %%
# Load TFLite model
interpreter = tf.lite.Interpreter(model_path="drug_effectiveness.tflite")
interpreter.allocate_tensors() # Allocates memory for the model's input and output tensors

# Get input and output tensors
input_details = interpreter.get_input_details() # Shape, Data type, Index
output_details = interpreter.get_output_details()

# Prepare new input data (replace with your data)
new_data_tflite = np.array([[-1.8653,  2.3106,  0.3982,  0.6221, -0.0886,  0.4502,  0.8476,  0.3480, 0.0992, -0.4730,  0.1709, -3.2441,  0.4826,  0.5644, -1.1889, -1.0514, 0.3332]], dtype=np.float32)
# [3.5, 2.1, 0.85, ...] represent features or variables that the model uses to make predictions

# Perform inference
interpreter.set_tensor(input_details[0]['index'], new_data_tflite) #input data (as a NumPy array) to index of the input tensor to which the data should be assigned
interpreter.invoke() #  model processes the input tensor, applies its trained parameters (weights and biases), and generates predictions
predicted_values = interpreter.get_tensor(output_details[0]['index']) 

print("Predicted IC50 Effectiveness (TFLite):", predicted_values)
# Out:
# Predicted IC50 Effectiveness (TFLite): [[0.3943677]]
# d:\Program_file\Anaconda\Lib\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
